# %%
import sys
sys.path.append('/home/arusia/fastai/airsim/AirSim/PythonClient')
import numpy as np
from AirSimClient import *

# %%
# connect to the AirSim simulator
client = MultirotorClient()
client.confirmConnection()
client.enableApiControl(True)
client.armDisarm(True)
# Out:
# Waiting for connection:
# True

# %%
import tempfile
import pprint
state = client.getMultirotorState()
s = pprint.pformat(state)

# %%
import matplotlib.pyplot as plt
def get_image():
    image_response = client.simGetImages([ImageRequest(0, AirSimImageType.Scene, False, False)])[0]
    image1d = np.fromstring(image_response.image_data_uint8, dtype=np.uint8)
    image_rgba = image1d.reshape(image_response.height, image_response.width, 4)
    
    return image_rgba
img=get_image()
plt.imshow(img)
plt.show()
# Out:
# /home/arusia/.local/lib/python3.5/site-packages/ipykernel_launcher.py:4: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   after removing the cwd from sys.path.

# %%
"""
For connecting to the AirSim drone environment and testing API functionality1
"""

import os
import tempfile
import pprint

from AirSimClient import *


# connect to the AirSim simulator

client = MultirotorClient()
client.confirmConnection()
client.enableApiControl(True)
client.armDisarm(True)
client.takeoff()
# Out:
# Waiting for connection:
# True

# %%
import time

state=client.getMultirotorState()
print(state.gps_location)
# Out:
# <GeoPoint> {   'altitude': 131.75363159179688,
#     'latitude': 47.64192159831662,
#     'longitude': -122.1394940783829}

# %%
client.moveToPosition(x=-50,y=150,z=-10,velocity=10)
# Out:
# True

# %%
import numpy as np
solar_coordinates = [3800,180,100]
def distance(coord):
    return np.sqrt(np.linalg.norm(coord-solar_coordinates))

# %%
import sys
sys.path.append('/home/arusia/fastai/airsim/AirSim/PythonClient')
import numpy as np
from AirSimClient import *

class x():
    call=0
    def __init__(self):
        self.client = MultirotorClient()
        self.client.confirmConnection()
        self.client.enableApiControl(True)
        self.client.armDisarm(True)
        self.client.takeoff()
    def reset(self):
        print('yes')
        self.client.reset()
        self.client.enableApiControl(False)
a=x()
# Out:
# Waiting for connection:
# yes

# %%
a.reset()
a=x()
# Out:
# yes
# Waiting for connection:

# %%
client = MultirotorClient()
client.confirmConnection()
client.enableApiControl(True)
`client.armDisarm(True)
client.takeoff()
client.getMultirotorState()
# Out:
# Waiting for connection:
# <MultirotorState> {   'collision': <CollisionInfo> {   'has_collided': False,
#     'impact_point': <Vector3r> {   'x_val': -0.33253905177116394,
#     'y_val': 0.3356523811817169,
#     'z_val': 0.873504102230072},
#     'normal': <Vector3r> {   'x_val': -9.536431973961035e-13,
#     'y_val': -1.1920148255741347e-19,
#     'z_val': -1.0},
#     'object_id': 116,
#     'object_name': 'Ground_5',
#     'penetration_depth': 0.0,
#     'position': <Vector3r> {   'x_val': 0.0,
#     'y_val': 0.0,
#     'z_val': 0.6815453767776489},
#     'time_stamp': 1465656001000},
#     'gps_location': <GeoPoint> {   'altitude': 123.49797058105469,
#     'latitude': 47.6414680480957,
#     'longitude': -122.14016723632812},
#     'kinematics_estimated': <KinematicsState> {   'angular_acceleration': <Vector3r> {   'x_val': 0.0,
#     'y_val': 0.0,
#     'z_val': 0.0},
#     'angular_velocity': <Vector3r> {   'x_val': 0.0,
#     'y_val': 0.0,
#     'z_val': 0.0},
# ...

# %%
a=x()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-971a964d1a89> in <module>()
# ----> 1 a=x()
#
# <ipython-input-2-8016c1068583> in __init__(self)
#      10     call=0
#      11     def __init__(self):
# ---> 12         client.takeoff()
#      13     def __del__(self):
#      14         client.reset()
#
# ~/fastai/airsim/AirSim/PythonClient/AirSimClient.py in takeoff(self, max_wait_seconds)
#     461
#     462     def takeoff(self, max_wait_seconds = 15):
# --> 463         return self.client.call('takeoff', max_wait_seconds)
#     464
#     465     def land(self, max_wait_seconds = 60):
#
# ~/.local/lib/python3.5/site-packages/msgpackrpc/session.py in call(self, method, *args)
#      39
#      40     def call(self, method, *args):
# ---> 41         return self.send_request(method, args).get()
#      42
#      43     def call_async(self, method, *args):
#
# ...

# %%
a.__del__()
